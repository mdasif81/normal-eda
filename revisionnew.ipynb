# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns

# %%
x=[1,2,3,4]
y=[1,40,2,3]
y_new=[]
for a in y:
    if a>4:
        y_new.append(4)
    else:
        y_new.append(a)

# %%
plt.plot(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("data over time")
# Out:
# Text(0.5, 1.0, 'data over time')

# %%
x=[1,2,3,4,5]
y=[10,20,30,40,50]

plt.plot(x,y)

# %%
x=["A","B","C","D","E"]
Y=[10,20,30,40,50]
plt.bar(x,y)
plt.xlabel("variable")
plt.ylabel("distance")
plt.title("distance over catogery")
# Out:
# Text(0.5, 1.0, 'distance over catogery')

# %%
plt.xlabel("variable")
plt.ylabel("distance")
plt.title("distance over catogery")
# Out:
# Text(0.5, 1.0, 'distance over catogery')

# %%
plt.barh(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
x=np.linspace(0,10,100)
y=np.sin(x)
plt.plot(x,y,color="red",linewidth=2)

# %%
plt.plot(x,y,color="#33ffe6",linewidth=2)

# %%
ax=plt.axes()
ax.set_facecolor("black")

# %%
df=sns.load_dataset("tips")
df.head()
sns.scatterplot(x="total_bill",y="tip",data=df,hue="smoker",color="red")
sns.lineplot(x="total_bill",y="tip",data=df,hue="sex",color="red")
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot
# Out:
# <function seaborn.distributions.histplot(data=None, *, x=None, y=None, hue=None, weights=None, stat='count', bins='auto', binwidth=None, binrange=None, discrete=None, cumulative=False, common_bins=True, common_norm=True, multiple='layer', element='bars', fill=True, shrink=1, kde=False, kde_kws=None, line_kws=None, thresh=0, pthresh=None, pmax=None, cbar=False, cbar_ax=None, cbar_kws=None, palette=None, hue_order=None, hue_norm=None, color=None, log_scale=None, legend=True, ax=None, **kwargs)>

# %%
sns.histplot(x="total_bill",data=df,kde="True")
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='Count'>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some random data
data = np.random.normal(size=(100))

# Create a box plot
fig, ax = plt.subplots()
ax.boxplot(data)
ax.set_title('Box plot')
plt.show()

# %%
smokers=df[df["smoker"]=="Yes"]
non_smokers=df[df["smoker"]=="No"]
fig,(ax1,ax2)=plt.subplots(2,1,)


ax1.scatter(smokers["total_bill"],smokers["tip"],color="red",label="Yes")
ax1.set_title("smoker")
ax1.set_xlabel("total bill")
ax1.set_ylabel("tip")
ax.legend()

ax2.scatter(non_smokers["total_bill"],non_smokers["tip"],color="blue",label="No")
ax2.set_title("smoker")
ax2.set_xlabel("total bill")
ax2.set_ylabel("tip")
# Out:
# Text(0, 0.5, 'tip')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Given Data
tips_data = [
    (16.99, 1.01, 'Female','Mon', 'Dinner', 2),
    (10.34, 1.66, 'Male','Mon', 'Dinner', 3),
    (21.01, 3.5, 'Male', 'Tue', 'Dinner', 3),
    (23.68, 3.31, 'Male', 'Tue', 'Dinner', 2),
    (24.59, 3.61, 'Female','Tue', 'Dinner', 4),
    (25.29, 4.71, 'Male', 'Wed', 'Dinner', 4),
    (8.77, 2.0, 'Male','Thu', 'Dinner', 2),
    (26.88, 3.12, 'Male','Thu', 'Dinner', 4),
    (15.04, 1.96, 'Male','Sun', 'Dinner', 2),
    (14.78, 3.23, 'Male','Sun', 'Dinner', 2)
]

df=pd.DataFrame(tips_data, columns=["total_bill","tip","sex","day","time","size"])
tip_amount=df.groupby("day")["tip"].mean()
sns.barplot(x=tip_amount.index,y=tip_amount.values)                          ##because tip_amount is series type and series has only 1 index
sns.heatmap(data=df.corr(),annot=True,cmap="coolwarm")
# Out:
# <AxesSubplot: >

# %%
sns.boxplot(data=df,x="day",y="total_bill",hue="sex")
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(data=df, x="day", y="total_bill", hue="sex")
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
type(tip_amount)
# Out:
# pandas.core.series.Series

# %%
tip_amount.values
# Out:
# array([1.335     , 2.595     , 2.56      , 3.47333333, 4.71      ])

# %%
tip_amount.index
# Out:
# Index(['Mon', 'Sun', 'Thu', 'Tue', 'Wed'], dtype='object', name='day')

# %%
tip_amount=df.groupby("day")["tip"].mean()
tip_amount
# Out:
# day
# Mon    1.335000
# Sun    2.595000
# Thu    2.560000
# Tue    3.473333
# Wed    4.710000
# Name: tip, dtype: float64

# %%
df.groupby("sex")["tip"].mean()
# Out:
# sex
# Female    2.31000
# Male      2.93625
# Name: tip, dtype: float64

# %%
male=df[df["sex"]=="Male"]
smoker=df[df["smoker"]=="Yes"]
x.shape
# Out:
# (157, 7)

# %%
file_path="D:\Asif\data wrangling data\employee.csv"
data=pd.read_csv(file_path)
data
# Out:
#    id    name   age   gender department   salary
# 0    1    john    20    male         hr   500000
# 1    2    jane    23  female  marketing   600000
# 2    3    joey    23    male         it   300000
# 3    4   sarah    25  female         hr   450000
# 4    5    rose    28    male         hr   700000
# 5    6    bing    29    male    finance   800000
# 6    7    rach    41  female         it   600000
# 7    8  monica    23  female  marketing  7000000
# 8    9  pheebe    35  female         it  4000000

# %%
data[data["name "] == "sarah"]
# Out:
#    id   name   age   gender department  salary
# 3    4  sarah    25  female         hr  450000

# %%
data.shape
data.info
data.describe()
data.isnull()
# Out:
#      id   name    age   gender  department  salary
# 0  False  False  False   False       False   False
# 1  False  False  False   False       False   False
# 2  False  False  False   False       False   False
# 3  False  False  False   False       False   False
# 4  False  False  False   False       False   False
# 5  False  False  False   False       False   False
# 6  False  False  False   False       False   False
# 7  False  False  False   False       False   False
# 8  False  False  False   False       False   False

# %%
data_1=data.groupby("gender")["salary"].count()
data_1
# Out:
# gender
# female    5
# male      4
# Name: salary, dtype: int64

# %%
data_1=data.groupby("gender")["salary"].mean()
data_1
# Out:
# gender
# female    2530000.0
# male       575000.0
# Name: salary, dtype: float64

# %%
data_2=data.groupby("department")["salary"].sum()
data_2
# Out:
# department
# finance       800000
# hr           1650000
# it           4900000
# marketing    7600000
# Name: salary, dtype: int64

# %%
filepath="D:\Asif\jasondata\employee.json"
data_3=pd.read_json("D:\Asif\jasondata\employee.json")
data_3
# Out:
#    id    name   age   gender department   salary
# 0    1    john    20    male         hr   500000
# 1    2    jane    23  female  marketing   600000
# 2    3    joey    23    male         it   300000
# 3    4   sarah    25  female         hr   450000
# 4    5    rose    28    male         hr   700000
# 5    6    bing    29    male    finance   800000
# 6    7    rach    41  female         it   600000
# 7    8  monica    23  female  marketing  7000000
# 8    9  pheebe    35  female         it  4000000

# %%
data = [('2022-01-01', 10.1),
        ('2022-01-02', 8.9),
        ('2022-01-03', 6.3),
        ('2022-01-04', 7.2),
        ('2022-01-05', 5.6),
        ('2022-01-06', 4.8),
        ('2022-01-07', 6.5),
        ('2022-01-08', 9.2),
        ('2022-01-09', 11.8),
        ('2022-01-10', 12.6),
        ('2022-01-11', 9.5),
        ('2022-01-12', 8.3)]

df=pd.DataFrame(data,columns=["date",'temp'])
df_1=pd.to_datetime(df["date"])
plt.rcParams.update({"font.size":8})
plt.plot(df["date"],df["temp"])

# %%
sns.lineplot(data=df,x="date",y="temp")
# Out:
# <AxesSubplot: xlabel='date', ylabel='temp'>

# %%
df_1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df_1=sns.load_dataset("iris")
sns.violinplot(data=df_1,x="species",y="sepal_length")
# Out:
# <AxesSubplot: xlabel='species', ylabel='sepal_length'>

# %%
sns.pairplot(data=df_1,hue="species")

# %%
sns.heatmap(data=df_1.corr(),annot=True,cmap="coolwarm")
# Out:
# <AxesSubplot: >

# %%
titanic_data = [
    (1, "male", 22.0, 1, 0, 7.25, "Third", "S", "Survived"),
    (2, "female", 38.0, 1, 0, 71.2833, "First", "C", "Survived"),
    (3, "female", 26.0, 0, 0, 7.925, "Third", "S", "Died"),
    (4, "female", 35.0, 1, 0, 53.1, "First", "S", "Survived"),
    (5, "male", 35.0, 0, 0, 8.05, "Third", "S", "Died"),
    (6, "male", None, 0, 0, 18.4583, "Third", "Q", "Died"),
    (7, "male", 54.0, 0, 0, 51.8625, "First", "S", "Died"),
    (8, "male", 2.0, 3, 1, 21.075, "Second", "S", "Survived"),
    (9, "female", 27.0, 0, 2, 11.1333, "Third", "S", "Survived"),
    (10, "female", 14.0, 1, 0, 30.0708, "Second", "C", "Survived"),

]
titanic_df = pd.DataFrame(titanic_data, columns=["PassengerId", "Sex", "Age", "SibSp", "Parch", "Fare", "Class", "Embarked", "Survived"])
titanic_df
# Out:
#    PassengerId     Sex   Age  SibSp  Parch     Fare   Class Embarked  Survived
# 0            1    male  22.0      1      0   7.2500   Third        S  Survived
# 1            2  female  38.0      1      0  71.2833   First        C  Survived
# 2            3  female  26.0      0      0   7.9250   Third        S      Died
# 3            4  female  35.0      1      0  53.1000   First        S  Survived
# 4            5    male  35.0      0      0   8.0500   Third        S      Died
# 5            6    male   NaN      0      0  18.4583   Third        Q      Died
# 6            7    male  54.0      0      0  51.8625   First        S      Died
# 7            8    male   2.0      3      1  21.0750  Second        S  Survived
# 8            9  female  27.0      0      2  11.1333   Third        S  Survived
# 9           10  female  14.0      1      0  30.0708  Second        C  Survived

# %%
sns.boxplot(data=titanic_df,x="Class",y="Fare")
plt.xlabel("class")
plt.ylabel("fare")
plt.title("class wise fare distribution")
sns.heatmap(titanic_df.corr(), annot=True,cmap="coolwarm")
# Out:
# <AxesSubplot: title={'center': 'class wise fare distribution'}>

# %%
sns.heatmap(data=titanic_df[["Age","Fare","Parch","SibSp"]].corr(),annot=True,cmap="coolwarm")
# Out:
# <AxesSubplot: >

# %%
numeric_titanic_df=titanic_df.select_dtypes(include=["number"])
sns.heatmap(numeric_titanic_df.corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot: >

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
file_path = r"D:\Asif\eda_automobile.csv\automobile.csv"
df = pd.read_csv(file_path)
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.shape
# Out:
# (12, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df.groupby("symboling")["price"].count()
# Out:
# symboling
# -2     3
# -1    22
#  0    67
#  1    54
#  2    32
#  3    27
# Name: price, dtype: int64
